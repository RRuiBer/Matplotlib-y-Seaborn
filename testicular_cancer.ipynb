# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
testicular_cancer = pd.read_csv('/mnt/d/Users/Ricardo/Cursos/6_matplotlib_seaborn/proyecto/Testicular Cancer.csv')
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage I':
        stageI = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[0].copy()
        testicular_cancer.iloc[0] = stageI
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IA':
        stageIA = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[1].copy()
        testicular_cancer.iloc[1] = stageIA
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IB':
        stageIB = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[2].copy()
        testicular_cancer.iloc[2] = stageIB
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IS':
        stageIS = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[3].copy()
        testicular_cancer.iloc[3] = stageIS
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage II':
        stageII = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[4].copy()
        testicular_cancer.iloc[4] = stageII
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIA':
        stageIIA = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[5].copy()
        testicular_cancer.iloc[5] = stageIIA
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIB':
        stageIIB = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[6].copy()
        testicular_cancer.iloc[6] = stageIIB
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIC':
        stageIIC = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[7].copy()
        testicular_cancer.iloc[7] = stageIIC
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage III':
        stageIII = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[8].copy()
        testicular_cancer.iloc[8] = stageIII
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIIA':
        stageIIIA = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[9].copy()
        testicular_cancer.iloc[9] = stageIIIA
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIIB':
        stageIIIB = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[10].copy()
        testicular_cancer.iloc[10] = stageIIIB
        testicular_cancer.iloc[i] = stage
for i in range(testicular_cancer.shape[0]):
    if testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].iloc[i] == 'Stage IIIC':
        stageIIIC = testicular_cancer.iloc[i].copy()
        stage = testicular_cancer.iloc[11].copy()
        testicular_cancer.iloc[11] = stageIIIC
        testicular_cancer.iloc[i] = stage
testicular_cancer.head(15)
# Out:
#      Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0   tgct_tcga  TCGA-XY-A8S2  TCGA-XY-A8S2-01           67.0
# 1   tgct_tcga  TCGA-ZM-AA0F  TCGA-ZM-AA0F-01           35.0
# 2   tgct_tcga  TCGA-ZM-AA0N  TCGA-ZM-AA0N-01           44.0
# 3   tgct_tcga  TCGA-ZM-AA0H  TCGA-ZM-AA0H-01           50.0
# 4   tgct_tcga  TCGA-2X-A9D5  TCGA-2X-A9D5-01           49.0
# 5   tgct_tcga  TCGA-2G-AAKM  TCGA-2G-AAKM-01           14.0
# 6   tgct_tcga  TCGA-2G-AAFH  TCGA-2G-AAFH-01           38.0
# 7   tgct_tcga  TCGA-ZM-AA05  TCGA-ZM-AA05-01           36.0
# 8   tgct_tcga  TCGA-2G-AAKD  TCGA-2G-AAKD-01           18.0
# 9   tgct_tcga  TCGA-2G-AAGZ  TCGA-2G-AAGZ-01           27.0
# 10  tgct_tcga  TCGA-YU-A94D  TCGA-YU-A94D-01           28.0
# 11  tgct_tcga  TCGA-YU-AA4L  TCGA-YU-AA4L-01           27.0
# 12  tgct_tcga  TCGA-2G-AAFI  TCGA-2G-AAFI-01           41.0
# 13  tgct_tcga  TCGA-2G-AAFE  TCGA-2G-AAFE-01           37.0
# 14  tgct_tcga  TCGA-2G-AAFG  TCGA-2G-AAFG-05           30.0
#
# ...

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code') # gráfico de distribución
plt.xticks(rotation=45)
plt.xlabel('Neoplasm Disease Stage American\nJoint Committee on Cancer Code')
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age') # relación x,y
plt.xticks(rotation=45)
plt.xlabel('Neoplasm Disease Stage American\nJoint Committee on Cancer Code')
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age',hue='Cancer Type Detailed') # relación x,y
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed') # relación x,y
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed',multiple='dodge')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.countplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()

# %%
sns.stripplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.swarmplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_723/636264756.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
ax = sns.scatterplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_723/2142040112.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
sns.displot(data=testicular_cancer, x='Diagnosis Age',bins=30) # gráfico de distribución
plt.show()

# %%
sns.kdeplot(data=testicular_cancer, x='Diagnosis Age') # gráfico de distribución
plt.show()

# %% [markdown]
# Referenciar la fuente
#
# crear el MD para subir a github
