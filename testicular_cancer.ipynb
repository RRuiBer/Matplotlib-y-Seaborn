# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
testicular_cancer = pd.read_csv('/mnt/d/Users/Ricardo/Cursos/6_matplotlib_seaborn/proyecto/Testicular Cancer.csv')
stageI = testicular_cancer.iloc[11].copy()
stageIS  = testicular_cancer.iloc[0].copy()
testicular_cancer.iloc[0] = stageI
testicular_cancer.iloc[11] = stageIS
stageIA = testicular_cancer.iloc[3].copy()
stageIS  = testicular_cancer.iloc[1].copy()
testicular_cancer.iloc[1] = stageIA
testicular_cancer.iloc[3] = stageIS
stageIB = testicular_cancer.iloc[10].copy()
stageIS  = testicular_cancer.iloc[2].copy()
testicular_cancer.iloc[2] = stageIB
testicular_cancer.iloc[10] = stageIS
stageII = testicular_cancer.iloc[50].copy()
stageIS  = testicular_cancer.iloc[4].copy()
testicular_cancer.iloc[4] = stageII
testicular_cancer.iloc[50] = stageIS
stageIIC = testicular_cancer.iloc[148].copy()
stageIS  = testicular_cancer.iloc[10].copy()
testicular_cancer.iloc[10] = stageIIC
testicular_cancer.iloc[148] = stageIS
stageIII = testicular_cancer.iloc[60].copy()
stageIS  = testicular_cancer.iloc[11].copy()
testicular_cancer.iloc[11] = stageIII
testicular_cancer.iloc[60] = stageIS
stageIIIA = testicular_cancer.iloc[46].copy()
stageIS  = testicular_cancer.iloc[12].copy()
testicular_cancer.iloc[12] = stageIIIA
testicular_cancer.iloc[60] = stageIS
testicular_cancer.head(5)
# Out:
#     Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0  tgct_tcga  TCGA-2G-AAFJ  TCGA-2G-AAFJ-01           23.0
# 1  tgct_tcga  TCGA-2G-AAF4  TCGA-2G-AAF4-01           30.0
# 2  tgct_tcga  TCGA-2G-AAFI  TCGA-2G-AAFI-01           41.0
# 3  tgct_tcga  TCGA-2G-AAEX  TCGA-2G-AAEX-01           38.0
# 4  tgct_tcga  TCGA-2G-AAH4  TCGA-2G-AAH4-01           34.0
#
#   Neoplasm Disease Stage American Joint Committee on Cancer Code  \
# 0                                            Stage I
# 1                                           Stage IA
# 2                                           Stage IB
# 3                                           Stage IS
# 4                                           Stage II
#
#   Neoplasm American Joint Committee on Cancer Clinical Distant Metastasis M Stage  \
# 0                                                 M0
# 1                                                 M0
# 2                                                 M0
# 3                                                 M0
# 4                                                 M0
#
#   American Joint Committee on Cancer Metastasis Stage Code  \
# 0                                                 M0
# 1                                                 M0
# 2                                                 M0
# 3                                                 M0
# 4                                                 M0
#
#   American Joint Committee on Cancer Lymph Node Stage Code.1  \
# 0                                                 N0
# 1                                                 N0
# 2                                                 N0
# 3                                                 N0
# 4                                                 N1
#
#   American Joint Committee on Cancer Lymph Node Stage Code  \
# 0                                                 T1
# 1                                                 T1
# 2                                                 T2
# 3                                                 T1
# 4                                                 T1
#
#   Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code  \
# 0                                                 N0
# 1                                                 N0
# 2                                                 N0
# 3                                                 N0
# 4                                                 NX
#
#    ... Serum markers   Sex Tumor Tissue Site Somatic Status  \
# 0  ...            S2  Male            Testes        Matched
# 1  ...            S0  Male            Testes        Matched
# 2  ...            S2  Male            Testes        Matched
# 3  ...            S1  Male            Testes        Matched
# 4  ...            S2  Male            Testes        Matched
#
#                             Testis tumor macroextent  \
# 0                               Involves testis only
# 1                               Involves testis only
# 2                               Involves testis only
# 3  Involves extratesticular structures: Tunica al...
# 4                               Involves testis only
#
#    Testis tumor microextent  Tissue Source Site  TMB (nonsynonymous)  \
# 0                       NaN                  2G             1.966667
# 1               Rete Testis                  2G             1.500000
# 2               Rete Testis                  2G             1.633333
# 3                       NaN                  2G             1.933333
# 4                       NaN                  2G             2.100000
#
#    Person Neoplasm Status  Vial number
# 0              TUMOR FREE            A
# 1              TUMOR FREE            A
# 2              TUMOR FREE            A
# 3              TUMOR FREE            A
# 4              TUMOR FREE            A
#
# [5 rows x 88 columns]

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code') # gráfico de distribución
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age') # relación x,y
plt.xticks(rotation=45)
plt.show()  # Rotar las etiquetas

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age',hue='Cancer Type Detailed') # relación x,y
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed') # relación x,y
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed',multiple='dodge')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.countplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()

# %%
sns.stripplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.swarmplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_717/636264756.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
ax = sns.scatterplot(data=testicular_cancer, x='Neoplasm Disease Stage American Joint Committee on Cancer Code',y='Diagnosis Age',hue='Cancer Type Detailed')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_717/2142040112.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
datos_en_x = {'Stage I',
'Stage IA',
'Stage IB',
'Stage IS',
'Stage II',
'Stage IIA',
'Stage IIB',
'Stage IIC',
'Stage III',
'Stage IIIA',
'Stage IIIB',
'Stage IIIC'}

print(testicular_cancer['Neoplasm Disease Stage American Joint Committee on Cancer Code'].value_counts())
# Out:
# Neoplasm Disease Stage American Joint Committee on Cancer Code
# Stage IS      45
# Stage IA      27
# Stage I       15
# Stage IIA     11
# Stage IB      10
# Stage IIIB     8
# Stage IIIC     5
# Stage II       4
# Stage IIIA     2
# Stage IIB      1
# Stage IIC      1
# Stage III      1
# Name: count, dtype: int64

# %%
sns.displot(data=testicular_cancer, x='Diagnosis Age',bins=30) # gráfico de distribución
plt.show()

# %%
sns.kdeplot(data=testicular_cancer, x='Diagnosis Age') # gráfico de distribución
plt.show()

# %% [markdown]
# Referenciar la fuente
